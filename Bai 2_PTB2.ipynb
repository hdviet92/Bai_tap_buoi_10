# %%
# Nhập dữ liệu
abc = input('Nhập 3 số a, b c bất kỳ cho phương trình bậc 2 ax^2 + bx + c = 0 : ').strip()
abc = abc.split(' ')
a = abc[0]
b = abc[1]
c = abc[2]

# Điều kiện dữ liệu đầu vào
if a.replace('-','').replace('.','').isdigit()==True and b.replace('-','').replace('.','').isdigit()==True and c.replace('-','').replace('.','').isdigit()==True:
    a = float(abc[0])
    b = float(abc[1])
    c = float(abc[2])
    
    # Xuất công thức với a = 0 hoặc b = 0
    if a != 0 and b != 0 and c != 0:
        if a == 1 and a != -1 and b != 1 and b != -1:
            a = ''
        elif a == -1 and a != 1 and b != 1 and b != -1:
            a = '-'
        elif b == 1 and a != 1 and a != -1 and b != -1: 
            b = ''
        elif b == -1 and a != 1 and a != -1 and b != 1: 
            b = '-' 
        elif a == 1 and b == 1 and a != -1 and b != -1:
            a = ''
            b = ''
        elif a == -1 and b == -1 and a != 1 and b != 1:
            a = '-'
            b = '-'
        elif a == 1 and b == -1 and a != -1 and b != 1:
            a = ''
            b = '-'
        elif a == -1 and b == 1 and a != 1 and b != -1:
            a = '-'
            b = ''
        print('Phương trình bậc 2: {a}x^2 + {b}x + {c} = 0'.format(a=a, b=b, c=c))
    
    if a != 0 and b != 0 and c == 0:
        if a == 1 and a != -1 and b != 1 and b != -1:
            a = ''
        elif a == -1 and a != 1 and b != 1 and b != -1:
            a = '-'
        elif b == 1 and a != 1 and a != -1 and b != -1: 
            b = ''
        elif b == -1 and a != 1 and a != -1 and b != 1: 
            b = '-' 
        elif a == 1 and b == 1 and a != -1 and b != -1:
            a = ''
            b = ''
        elif a == -1 and b == -1 and a != 1 and b != 1:
            a = '-'
            b = '-'
        elif a == 1 and b == -1 and a != -1 and b != 1:
            a = ''
            b = '-'
        elif a == -1 and b == 1 and a != 1 and b != -1:
            a = '-'
            b = ''
        print('Phương trình bậc 2: {a}x^2 + {b}x = 0'.format(a=a, b=b))
        
    if a == 0 and b != 0 and c != 0:

        if b == 1 and b != -1: 
            b = ''
        elif b == -1 and b != 1: 
            b = '-' 
        print('Phương trình bậc 2: {b}x + {c} = 0'.format(b=b, c=c))
        
    if a != 0 and b == 0 and c != 0:
        if a == 1 and a != -1:
            a = ''
        elif a == -1 and a != 1:
            a = '-'
        print('Phương trình bậc 2: {a}x^2 + {c} = 0'.format(a=a, c=c))
    
    if a == 0 and b != 0 and c == 0:
        print('Phương trình bậc 2 có 1 nghiệm x = 0 ')
    
    if a != 0 and b == 0 and c == 0:
        print('Phương trình bậc 2 có 1 nghiệm x = 0 ')
        
    if a == 0 and b == 0 and c != 0:
        print('Phương trình bậc 2 vô nghiệm ')
        
    if a == 0 and b == 0 and c == 0:
        print('Phương trình bậc 2 có vô số nghiệm ') 
        
        
        
        
        
        
else:
    print
